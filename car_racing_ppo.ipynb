# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
import gym
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import VecFrameStack
from stable_baselines3.common.evaluation import evaluate_policy
from gym.wrappers import TimeLimit
import os

# %%
environment_name = "CarRacing-v2"
env = gym.make(environment_name,
               render_mode="human",
               #domain_randomize=True,
               #continuous=False,
              )
               
#env = TimeLimit(env, max_episode_steps=600)
env.reset()
env.render()
# Out:
# True

# %%
#env.close()

# %%
print("action space:{}".format(env.action_space))
print("observation space:{}".format(env.observation_space))
# Out:
# action space:Box([-1.  0.  0.], 1.0, (3,), float32)
# observation space:Box(0, 255, (96, 96, 3), uint8)

# %%
log_path = os.path.join('Training_car_PPO', 'Logs_car_PPO')

# %%
model = PPO('MlpPolicy', env, verbose=1, tensorboard_log=log_path)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.
# /home/estelle/miniconda3/envs/rlnavenv/lib/python3.8/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(

# %%
model.learn(total_timesteps=50000)
# Out:
# Logging to Training_car_PPO/Logs_car_PPO/PPO_3
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -30.8    |
# | time/              |          |
# |    fps             | 38       |
# |    iterations      | 1        |
# |    time_elapsed    | 52       |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -47.4       |
# | time/                   |             |
# |    fps                  | 34          |
# |    iterations           | 2           |
# |    time_elapsed         | 117         |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.007883645 |
# |    clip_fraction        | 0.0626      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.29       |
# |    explained_variance   | 0.0468      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.4         |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.00173    |
# |    std                  | 0.722       |
# |    value_loss           | 7.89        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -52.9        |
# | time/                   |              |
# |    fps                  | 33           |
# |    iterations           | 3            |
# |    time_elapsed         | 185          |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0069282274 |
# |    clip_fraction        | 0.0584       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.25        |
# |    explained_variance   | 0.14         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.764        |
# |    n_updates            | 520          |
# |    policy_gradient_loss | -0.00164     |
# |    std                  | 0.712        |
# |    value_loss           | 1.97         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -55.1        |
# | time/                   |              |
# |    fps                  | 33           |
# |    iterations           | 4            |
# |    time_elapsed         | 246          |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0048156716 |
# |    clip_fraction        | 0.033        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.24        |
# |    explained_variance   | 0.15         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.669        |
# |    n_updates            | 530          |
# |    policy_gradient_loss | 0.00113      |
# |    std                  | 0.712        |
# |    value_loss           | 1.57         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -56.9       |
# | time/                   |             |
# |    fps                  | 34          |
# |    iterations           | 5           |
# |    time_elapsed         | 300         |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.007662463 |
# |    clip_fraction        | 0.0598      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.22       |
# |    explained_variance   | 0.109       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.96        |
# |    n_updates            | 540         |
# |    policy_gradient_loss | -0.00129    |
# |    std                  | 0.707       |
# |    value_loss           | 2.55        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -58.1       |
# | time/                   |             |
# |    fps                  | 34          |
# |    iterations           | 6           |
# |    time_elapsed         | 352         |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.010446018 |
# |    clip_fraction        | 0.0807      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.19       |
# |    explained_variance   | 0.195       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.297       |
# |    n_updates            | 550         |
# |    policy_gradient_loss | -0.00394    |
# |    std                  | 0.698       |
# |    value_loss           | 1.67        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -55.5        |
# | time/                   |              |
# |    fps                  | 35           |
# |    iterations           | 7            |
# |    time_elapsed         | 406          |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0074535455 |
# |    clip_fraction        | 0.0576       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.15        |
# |    explained_variance   | 0.176        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.18         |
# |    n_updates            | 560          |
# |    policy_gradient_loss | -0.00197     |
# |    std                  | 0.687        |
# |    value_loss           | 1.52         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -52.8        |
# | time/                   |              |
# |    fps                  | 35           |
# |    iterations           | 8            |
# |    time_elapsed         | 460          |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0060653747 |
# |    clip_fraction        | 0.049        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.11        |
# |    explained_variance   | 0.0644       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.41         |
# |    n_updates            | 570          |
# |    policy_gradient_loss | -0.00175     |
# |    std                  | 0.68         |
# |    value_loss           | 4.62         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -50         |
# | time/                   |             |
# |    fps                  | 35          |
# |    iterations           | 9           |
# |    time_elapsed         | 523         |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.005789144 |
# |    clip_fraction        | 0.0688      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.07       |
# |    explained_variance   | 0.0783      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.26        |
# |    n_updates            | 580         |
# |    policy_gradient_loss | -0.00355    |
# |    std                  | 0.669       |
# |    value_loss           | 5.44        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 984          |
# |    ep_rew_mean          | -53.9        |
# | time/                   |              |
# |    fps                  | 35           |
# |    iterations           | 10           |
# |    time_elapsed         | 580          |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0008653721 |
# |    clip_fraction        | 0.0148       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.04        |
# |    explained_variance   | 0.063        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.38         |
# |    n_updates            | 590          |
# |    policy_gradient_loss | 0.000851     |
# |    std                  | 0.664        |
# |    value_loss           | 5.28         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 985         |
# |    ep_rew_mean          | -53.2       |
# | time/                   |             |
# |    fps                  | 35          |
# |    iterations           | 11          |
# |    time_elapsed         | 634         |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.007947596 |
# |    clip_fraction        | 0.104       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.02       |
# |    explained_variance   | -0.0808     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.238       |
# |    n_updates            | 600         |
# |    policy_gradient_loss | -0.00334    |
# |    std                  | 0.663       |
# |    value_loss           | 25.5        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 986          |
# |    ep_rew_mean          | -52          |
# | time/                   |              |
# |    fps                  | 35           |
# |    iterations           | 12           |
# |    time_elapsed         | 695          |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0070042624 |
# |    clip_fraction        | 0.0513       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3           |
# |    explained_variance   | 0.0223       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.25         |
# |    n_updates            | 610          |
# |    policy_gradient_loss | -0.000962    |
# |    std                  | 0.657        |
# |    value_loss           | 5.53         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 987         |
# |    ep_rew_mean          | -50.2       |
# | time/                   |             |
# |    fps                  | 35          |
# |    iterations           | 13          |
# |    time_elapsed         | 753         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.004091312 |
# |    clip_fraction        | 0.025       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3          |
# |    explained_variance   | 0.0466      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.33        |
# |    n_updates            | 620         |
# |    policy_gradient_loss | 0.000268    |
# |    std                  | 0.66        |
# |    value_loss           | 5.47        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 989          |
# |    ep_rew_mean          | -47.7        |
# | time/                   |              |
# |    fps                  | 35           |
# |    iterations           | 14           |
# |    time_elapsed         | 812          |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0058387564 |
# |    clip_fraction        | 0.0687       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3           |
# |    explained_variance   | 0.061        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.3          |
# |    n_updates            | 630          |
# |    policy_gradient_loss | -0.00319     |
# |    std                  | 0.659        |
# |    value_loss           | 4.5          |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 989        |
# |    ep_rew_mean          | -48.1      |
# | time/                   |            |
# |    fps                  | 35         |
# |    iterations           | 15         |
# |    time_elapsed         | 870        |
# |    total_timesteps      | 30720      |
# | train/                  |            |
# |    approx_kl            | 0.00446544 |
# |    clip_fraction        | 0.0532     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.99      |
# |    explained_variance   | -0.023     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 3.19       |
# |    n_updates            | 640        |
# |    policy_gradient_loss | -0.00205   |
# |    std                  | 0.656      |
# |    value_loss           | 4.92       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 990         |
# |    ep_rew_mean          | -48.6       |
# | time/                   |             |
# |    fps                  | 35          |
# |    iterations           | 16          |
# |    time_elapsed         | 935         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.004685064 |
# |    clip_fraction        | 0.0471      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.98       |
# |    explained_variance   | 0.102       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.34        |
# |    n_updates            | 650         |
# |    policy_gradient_loss | 9.21e-05    |
# |    std                  | 0.653       |
# |    value_loss           | 3.23        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 991          |
# |    ep_rew_mean          | -50.2        |
# | time/                   |              |
# |    fps                  | 34           |
# |    iterations           | 17           |
# |    time_elapsed         | 996          |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0075739305 |
# |    clip_fraction        | 0.0627       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.96        |
# |    explained_variance   | 0.147        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.05         |
# |    n_updates            | 660          |
# |    policy_gradient_loss | -0.0011      |
# |    std                  | 0.648        |
# |    value_loss           | 2.16         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 991         |
# |    ep_rew_mean          | -51.7       |
# | time/                   |             |
# |    fps                  | 34          |
# |    iterations           | 18          |
# |    time_elapsed         | 1061        |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.008185428 |
# |    clip_fraction        | 0.064       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.92       |
# |    explained_variance   | 0.314       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.209       |
# |    n_updates            | 670         |
# |    policy_gradient_loss | -0.000804   |
# |    std                  | 0.636       |
# |    value_loss           | 1.01        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 992          |
# |    ep_rew_mean          | -52.5        |
# | time/                   |              |
# |    fps                  | 34           |
# |    iterations           | 19           |
# |    time_elapsed         | 1124         |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0066503086 |
# |    clip_fraction        | 0.0535       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.87        |
# |    explained_variance   | 0.279        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.438        |
# |    n_updates            | 680          |
# |    policy_gradient_loss | 2.68e-05     |
# |    std                  | 0.627        |
# |    value_loss           | 0.748        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 992         |
# |    ep_rew_mean          | -53.2       |
# | time/                   |             |
# |    fps                  | 34          |
# |    iterations           | 20          |
# |    time_elapsed         | 1184        |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.007069406 |
# |    clip_fraction        | 0.055       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.81       |
# |    explained_variance   | 0.242       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.586       |
# |    n_updates            | 690         |
# |    policy_gradient_loss | -0.00152    |
# |    std                  | 0.614       |
# |    value_loss           | 1.2         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 992         |
# |    ep_rew_mean          | -54.2       |
# | time/                   |             |
# |    fps                  | 34          |
# |    iterations           | 21          |
# |    time_elapsed         | 1248        |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.001996941 |
# |    clip_fraction        | 0.0518      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.77       |
# |    explained_variance   | 0.27        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.803       |
# |    n_updates            | 700         |
# |    policy_gradient_loss | -0.000963   |
# |    std                  | 0.609       |
# |    value_loss           | 1.4         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 993          |
# |    ep_rew_mean          | -55          |
# | time/                   |              |
# |    fps                  | 34           |
# |    iterations           | 22           |
# |    time_elapsed         | 1309         |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0049794125 |
# |    clip_fraction        | 0.066        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.74        |
# |    explained_variance   | 0.518        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.144        |
# |    n_updates            | 710          |
# |    policy_gradient_loss | -0.00141     |
# |    std                  | 0.601        |
# |    value_loss           | 0.458        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 993         |
# |    ep_rew_mean          | -54.6       |
# | time/                   |             |
# |    fps                  | 34          |
# |    iterations           | 23          |
# |    time_elapsed         | 1369        |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.004402755 |
# |    clip_fraction        | 0.0491      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.72       |
# |    explained_variance   | 0.159       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.44        |
# |    n_updates            | 720         |
# |    policy_gradient_loss | -0.000395   |
# |    std                  | 0.602       |
# |    value_loss           | 2.46        |
# -----------------------------------------

# %%
ppo_path = os.path.join('Training_car_PPO', 'Saved Models_car_PPO', 'PPO_car_model')

# %%
model.save(ppo_path)
